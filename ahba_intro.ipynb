# %% [markdown]
# ## Fetching AHBA Data

# %%
import abagen
from abagen import reporting
import nibabel as nib
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# To obtain data from all available donors, pass in ```donors='all'``` instead of a donor list.

# %%
files = abagen.fetch_microarray(donors=['9861', '10021'], verbose=0, data_dir='./data')

# %% [markdown]
# ## Loading AHBA Data

# %% [markdown]
# #### See the Reference API on [abagen.io](https://abagen.readthedocs.io/en/latest/api.html#module-abagen.io) for a comprehensive list of functions that assist with loading ABHA data files.

# %%
# List donor ID keys
print(files.keys())

# List the downloaded files available for donor 9861
sorted(files['9861'])
# Out:
# dict_keys(['9861', '10021'])
# ['annotation', 'microarray', 'ontology', 'pacall', 'probes']

# %%
# Print the annotation for donor 9861
data = files['9861']
annotation = abagen.io.read_annotation(data['annotation'])
annotation
# Out:
#            structure_id  slab_num  well_id slab_type structure_acronym  \
# sample_id
# 1                  4077        22      594        CX            PCLa-i
# 2                  4323        11     2985        CX                Cl
# 3                  4323        18     2801        CX                Cl
# 4                  4440        18     2273        CX               LGd
# 5                  4266        17     2785        CX               CA4
# ...                 ...       ...      ...       ...               ...
# 942                4751        67     1090        CB            PV-III
# 943                4752        67     1082        CB             PV-IV
# 944                4758        67     1074        CB           PV-VIIB
# 945                4760        67     1058        CB          PV-VIIIB
# 946                4761        67     1145        CB             PV-IX
#
#                                               structure_name  polygon_id  \
# sample_id
# 1          paracentral lobule, anterior part, right, infe...       37470
# 2                                           claustrum, right       40517
# 3                                           claustrum, right       41516
# 4                    dorsal lateral geniculate nucleus, left       41473
# 5                                           CA4 field, right       41142
# ...                                                      ...         ...
# 942                                   III, right, paravermis       51241
# 943                                    IV, right, paravermis       51239
# 944                                  VIIB, right, paravermis       56063
# 945                                 VIIIB, right, paravermis       56061
# 946                                    IX, right, paravermis       56059
#
#            mri_voxel_x  mri_voxel_y  mri_voxel_z  mni_x  mni_y  mni_z
# sample_id
# 1                   87           52          116    5.9  -27.7   49.7
# 2                   66           92           63   29.2   17.0   -2.9
# 3                   66           81          104   28.2  -22.8   16.8
# 4                  116           94          101  -24.6  -24.6    1.3
# 5                   63          104          106   31.1  -31.3   -7.3
# ...                ...          ...          ...    ...    ...    ...
# 942                 84          119          113    8.7  -43.4  -22.4
# 943                 84          108          122    8.5  -49.7   -8.9
# 944                 84          140          135    7.9  -72.3  -40.6
# 945                 84          154          117    8.3  -57.4  -59.0
# 946                 83          142          110    9.6  -46.7  -47.6
#
# [946 rows x 13 columns]

# %%
# Print the probes for donor 9861
probes = abagen.io.read_probes(data['probes'])
probes
# Out:
#                       probe_name  gene_id   gene_symbol  \
# probe_id
# 1058685              A_23_P20713      729           C8G
# 1058684   CUST_15185_PI416261804      731            C9
# 1058683             A_32_P203917      731            C9
# 1058682             A_23_P138819      736        MRPL49
# 1058681             A_24_P232500      736        MRPL49
# ...                          ...      ...           ...
# 1071207              A_32_P69683  1012195   A_32_P69683
# 1071208              A_32_P87582  1012196   A_32_P87582
# 1071209             A_32_P885445  1012197  A_32_P885445
# 1071210               A_32_P9207  1012198    A_32_P9207
# 1071211              A_32_P94122  1012199   A_32_P94122
#
#                                           gene_name  entrez_id chromosome
# probe_id
# 1058685   complement component 8, gamma polypeptide        733          9
# 1058684                      complement component 9        735          5
# 1058683                      complement component 9        735          5
# 1058682         mitochondrial ribosomal protein L49        740         11
# 1058681         mitochondrial ribosomal protein L49        740         11
# ...                                             ...        ...        ...
# 1071207      AGILENT probe A_32_P69683 (non-RefSeq)       <NA>        NaN
# 1071208      AGILENT probe A_32_P87582 (non-RefSeq)       <NA>        NaN
# 1071209     AGILENT probe A_32_P885445 (non-RefSeq)       <NA>        NaN
# 1071210       AGILENT probe A_32_P9207 (non-RefSeq)       <NA>        NaN
# 1071211      AGILENT probe A_32_P94122 (non-RefSeq)       <NA>        NaN
#
# [58692 rows x 6 columns]

# %% [markdown]
# ## Parcellations

# %% [markdown]
# #### Demo Parcellation

# %% [markdown]
# ```abagen.fetch_desikan_killiany``` will return a dictionary with two keys:
# 1. ```image```: Filepath to a NIFTI image containing the atlas data.
# 2. ```info```: Filepath to a CSV file containing extra parcellation info.

# %%
atlas = abagen.fetch_desikan_killiany()

im = nib.load(atlas['image'])

# Image type should be a 'nibabel.nifti1.Nifti1Image'
# print(type(im))

# View metadata
# print(im.header)

# Get the shape of the numpy array
im_data = im.get_fdata()
print(im_data.shape)

for i in range(10, len(im_data), 20):
    plt.imshow(im_data[i], cmap="bone")
    plt.axis('off')
    plt.show()
# Out:
# (146, 182, 155)

# %% [markdown]
# #### Individualized Parcellation

# %%
atlas = abagen.fetch_desikan_killiany(native=True)

for key in atlas['image']:
    im = nib.load(atlas['image'][key])
    im_data = im.get_fdata()
    print(f"Donor {key}")
    plt.imshow(im_data[100], cmap="bone")
    plt.axis('off')
    plt.show()
# Out:
# Donor 9861
# Donor 10021
# Donor 12876
# Donor 14380
# Donor 15496
# Donor 15697

# %% [markdown]
# ## Parcellating Expression Data

# %% [markdown]
# #### See the [abagen docs](https://abagen.readthedocs.io/en/latest/user_guide/expression.html) for more information on parcellating expression data.

# %% [markdown]
# get_expression_data assigns [microarray](https://www.youtube.com/watch?v=NgRfc6atXQ8) gene expression data to the ROIs defined in the atlas['img'] argument. For our purposes, this is the Allen Human Brain atlas for each donor.
#
# Matching of microarray samples to parcels in atlas is done via a [multi-step process](https://abagen.readthedocs.io/en/stable/generated/abagen.get_expression_data.html):
# 1. Determine if the sample falls directly within a parcel.
#
# 2. Check to see if there are nearby parcels by slowly expanding the search space to include nearby voxels, up to a specified distance (specified via the tolerance parameter).
#
# 3. If there are multiple nearby parcels, the sample is assigned to the closest parcel, as determined by the parcel centroid.
#
# By default, data are normalized using a scaled robust [sigmoid function](https://en.wikipedia.org/wiki/Sigmoid_function) such that the expression values for a given gene will range from 0-1.
# A value of 0 indicates the region with the lowest gene expression, while a value of 1 indicates the region with the highest.
#
# Note that the generated pandas.DataFrame is an aggregate of the donor argument/s.
#
# Interpreting the DataFrame:
# - DataFrame rows correspond to region labels as defined in the atlas image.
# - DataFrame columns correspond to genes.
# - Entry values are microarray expression data normalized and aggregated across selected donors.

# %%
# Use all donor image data
# expression = abagen.get_expression_data(atlas['image'])

# When using a volumetric image, it is recommended to include the additional information on the parcellation
# Note that the following function call loads all our specified donor data into memory, and will therefore be quite time-consuming
expression = abagen.get_expression_data(atlas['image'], atlas['info'], donors=['9861', '10021'])

expression
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  4 13  8 20  4  5  5  4 17  6  5  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  6 43  8 20  3  1 38  5  1  6  7  4 20  7 17  4  5  6
#   5 10 22  5  6  3  4  3  2 13  3 17  7  1 18 12  5 21  5  1  1  5 42 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  2  2 11 12  6  2  9  4  7 10  6  2  6  1  5  1 11  7  9  4  2
#  10 12  6  7  4  4  2  4 32  4 10  3  2 27  1  3  1  4  1 11  9 16  4  9
#   8  5  8  9  3  2  2  3  2  3 12  7  5  5  3 14 11  6  7  4  1  1  5 42
#   7 12  2  2 41  5]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)
# gene_symbol      A1BG  A1BG-AS1       A2M     A2ML1   A3GALT2    A4GALT  \
# label
# 1            0.411193  0.654636  0.311312  0.329412  0.343540  0.447728
# 2            0.702871  0.745297  0.540733  0.364332  0.586618  0.632237
# 3            0.511905  0.685144  0.450288  0.498516  0.479845  0.420458
# 4            0.196809  0.508313  0.300719  0.438814  0.526846  0.504038
# 5            0.611012  0.572926  0.582598  0.494148  0.325222  0.690626
# ...               ...       ...       ...       ...       ...       ...
# 78           0.676490  0.340506  0.630938  0.603608  0.457895  0.535835
# 79           0.844284  0.103433  0.857692  0.609372  0.322871  0.405863
# 80           0.847717  0.172526  0.723055  0.261526  0.468441  0.526045
# 81           0.392627  0.190657  0.517428  0.650158  0.702085  0.559050
# 82           0.815326  0.474236  0.428499  0.471620  0.371142  0.301578
#
# gene_symbol      AAAS      AACS   AADACL3     AADAT  ...      ZW10    ZWILCH  \
# label                                                ...
# 1            0.422514  0.651985  0.369602  0.690859  ...  0.564134  0.520868
# 2            0.492625  0.760038  0.378444  0.576240  ...  0.495737  0.638201
# 3            0.533825  0.774468  0.532429  0.534932  ...  0.597888  0.567729
# 4            0.683749  0.663107  0.563791  0.466360  ...  0.584433  0.602188
# 5            0.419007  0.682646  0.347780  0.494084  ...  0.346136  0.567190
# ...               ...       ...       ...       ...  ...       ...       ...
# 78           0.532403  0.201224  0.525418  0.552525  ...  0.469222  0.418451
# 79           0.573645  0.099089  0.647533  0.711668  ...  0.659773  0.390452
# 80           0.109316  0.088099  0.593683  0.581399  ...  0.462366  0.383693
# 81           0.361551  0.381946  0.770377  0.173541  ...  0.370980  0.333144
# 82           0.082115  0.316003  0.490592  0.810358  ...  0.357876  0.690924
#
# gene_symbol     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11B       ZYX  \
# label
# 1            0.558250  0.445564  0.515105  0.284892  0.600480  0.643322
# 2            0.392104  0.546040  0.439843  0.543519  0.504548  0.489840
# 3            0.512906  0.381439  0.532475  0.251144  0.719425  0.763599
# 4            0.396247  0.443990  0.495490  0.366986  0.722247  0.892999
# 5            0.665746  0.420981  0.419457  0.609152  0.609507  0.340740
# ...               ...       ...       ...       ...       ...       ...
# 78           0.374357  0.704933  0.502535  0.710287  0.210638  0.301288
# 79           0.326531  0.708577  0.534540  0.727375  0.233507  0.294042
# 80           0.722150  0.997021  0.586667  0.350898  0.536039  0.088321
# 81           0.629529  0.666735  0.497426  0.543701  0.279972  0.247870
# 82           0.688418  0.936600  0.564215  0.516948  0.083494  0.093367
#
# gene_symbol     ZZEF1      ZZZ3
# label
# 1            0.733896  0.481206
# 2            0.359517  0.504172
# 3            0.408600  0.435939
# 4            0.651316  0.374918
# 5            0.382410  0.682527
# ...               ...       ...
# 78           0.572658  0.573508
# 79           0.738417  0.814021
# 80           0.413000  0.769668
# 81           0.507926  0.397872
# 82           0.528905  0.795726
#
# [82 rows x 15332 columns]

# %%
# Note that some regions may not be matched to any tissue samples
nan_rows = expression.isna().any(axis=1)

for row, is_nan in nan_rows.items():
    if (is_nan):
        print(row, is_nan)

expression.loc[[18, 45]]
# Out:
# 18 True
# 45 True
# gene_symbol  A1BG  A1BG-AS1  A2M  A2ML1  A3GALT2  A4GALT  AAAS  AACS  AADACL3  \
# label
# 18            NaN       NaN  NaN    NaN      NaN     NaN   NaN   NaN      NaN
# 45            NaN       NaN  NaN    NaN      NaN     NaN   NaN   NaN      NaN
#
# gene_symbol  AADAT  ...  ZW10  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11B  ZYX  \
# label               ...
# 18             NaN  ...   NaN     NaN    NaN   NaN   NaN   NaN     NaN  NaN
# 45             NaN  ...   NaN     NaN    NaN   NaN   NaN   NaN     NaN  NaN
#
# gene_symbol  ZZEF1  ZZZ3
# label
# 18             NaN   NaN
# 45             NaN   NaN
#
# [2 rows x 15332 columns]

# %% [markdown]
# #### Ensuring a Dense Matrix

# %% [markdown]
# Microarray expression data may be missing (especially in right hemisphere regions), since not all donors have tissue samples for these areas.
#
# abagen.get_expression_data() takes the following steps for each tissue sample:
#
# 1. Determine if the sample falls directly within a region of ```atlas```.
# 2. Check to see if the sample is close to any regions by slowly expanding the search space to include nearby voxels up to a particular threshold (specified using the ```tolerance``` parameter).
# 3. If there are multiple nearby regions, determine which region is closer by calculating the center-of-mass of the abutting reions.
#
# Regions with no samples will have entry values of NaN.
# To resolve some/all empty entry values, we can utilize the two following techniques:
# 1. Use the ```missing``` parameter for localized data filling.
# 2. Duplicate samples across the main brain hemispheres with the ```lr_mirror``` parameter.

# %% [markdown]
# ##### Using the ```missing``` Parameter

# %% [markdown]
# The ```missing``` parameter accepts three options:
# 1. ```None``` (default)
# 2. ```centroids```: Empty regions in the atlas will be assigned the expression values of the tissue sample falling closest to the centroid of that region. This is only done when all donors are missing data for a particular region. A weighted average of the matched samples are taken across donors, where the weights are calculated as the inverse distance between the tissue sample matched to the parcel centroid for each donor.
# 3. ```interpolate```: Expression values will be interpolated in the empty regions by assigning every node in the region the expression of the nearest tissue sample. This interpolation is done independently for every donor, irrespective of whether other donors have tissue samples that fall within a given region.

# %%
# Setting the missing parameter will guarantee a dense expression matrix from an abagen.get_expression_data() function call
exp_centroids = abagen.get_expression_data(atlas['image'], atlas['info'], donors=['9861', '10021'], missing='centroids')

# Note that our NaN values have now been replaced with the nearest tissue expression values
exp_centroids.loc[[18, 45]]
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  4 13  8 20  4  5  5  4 17  6  5  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  6 43  8 20  3  1 38  5  1  6  7  4 20  7 17  4  5  6
#   5 10 22  5  6  3  4  3  2 13  3 17  7  1 18 12  5 21  5  1  1  5 42 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  2  2 11 12  6  2  9  4  7 10  6  2  6  1  5  1 11  7  9  4  2
#  10 12  6  7  4  4  2  4 32  4 10  3  2 27  1  3  1  4  1 11  9 16  4  9
#   8  5  8  9  3  2  2  3  2  3 12  7  5  5  3 14 11  6  7  4  1  1  5 42
#   7 12  2  2 41  5]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)
# gene_symbol      A1BG  A1BG-AS1       A2M     A2ML1   A3GALT2    A4GALT  \
# label
# 18           0.425979  0.840014  0.380376  0.306926  0.357608  0.350851
# 45           0.312873  0.575893  0.456839  0.393862  0.439561  0.479132
#
# gene_symbol      AAAS      AACS   AADACL3     AADAT  ...      ZW10    ZWILCH  \
# label                                                ...
# 18           0.587192  0.822059  0.177420  0.621199  ...  0.589104  0.664153
# 45           0.606960  0.661070  0.469461  0.639841  ...  0.397986  0.645063
#
# gene_symbol     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11B       ZYX  \
# label
# 18           0.583809  0.422938  0.462581  0.516629  0.853655  0.778874
# 45           0.526376  0.303711  0.488575  0.381814  0.614631  0.748325
#
# gene_symbol     ZZEF1      ZZZ3
# label
# 18           0.536883  0.692165
# 45           0.741187  0.435101
#
# [2 rows x 15332 columns]

# %% [markdown]
# ##### Duplicating Samples with the ```lr_mirror``` Parameter

# %% [markdown]
# Most regions in the left hemisphere are likely to be matched to at least one sample, while right-hemisphere regions are less likely. The ```lr_mirror``` parameter allows samples to be mirrored acorss the left/right hemisphere axis.
# The following four options are available for ```lr_mirror```:
# 1. ```None``` (default)
# 2. ```bidirectional```: All available samples from the left hemisphere are duplicated and mirrored to the right, and vice-versa from right to left.
# 3. ```leftright```: Mirror only the left hemisphere to the right.
# 4. ```rightleft```: Mirror only the right hemisphere to the left.

# %%
# The lr_mirror sample will not guarantee a dense matrix and will change the expression values of all regions, 
# not just those that are missing data
exp_mirror = abagen.get_expression_data(atlas['image'], atlas['info'], donors=['9861', '10021'], lr_mirror="bidirectional")

exp_mirror.loc[[18, 45]]
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 7  7 11  3  8 32 14 42  4 11 12  9 14 30  9 11  6  4  7  5 21  8 39  9
#   3 20 34  9 34 16  3  5 13 87 20 32  3  2 73  6  7 11 13  9 26 17 35  5
#   5 12 12 13 42 12 11  9  6 10  5 18  5 31 11  1 26 28 11 38 13  3  3  7
#  79 16 37  2  1 71  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 6  3 11  2  3 21 18 16  6 14  9 16 20 14  7  8  1  2  6  5 22 15 17  8
#   3 19 23 12 12  7  4  1  2 13 78 11 18  6  4 58  5  3  2  7  1  2 14 19
#  26  7 15 15  8 14 15  6  9  6  3  8  6 17 11 12 10  5 26 22 10 14  9  5
#   1  1  7 74 14 28  4  2 68  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)
# gene_symbol      A1BG  A1BG-AS1       A2M     A2ML1   A3GALT2    A4GALT  \
# label
# 18           0.498945  0.661866  0.432936  0.439732  0.552464  0.521205
# 45           0.107301  0.646866  0.260441  0.483639  0.243353  0.384010
#
# gene_symbol      AAAS      AACS   AADACL3     AADAT  ...      ZW10    ZWILCH  \
# label                                                ...
# 18           0.388407  0.758960  0.612760  0.451126  ...  0.556117  0.609156
# 45           0.700359  0.758787  0.474089  0.749774  ...  0.770688  0.669125
#
# gene_symbol     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11B       ZYX  \
# label
# 18           0.415659  0.492338  0.576034  0.489976  0.710067  0.578163
# 45           0.650266  0.487010  0.686296  0.254561  0.798310  0.975388
#
# gene_symbol     ZZEF1      ZZZ3
# label
# 18           0.321245  0.539873
# 45           0.905338  0.123992
#
# [2 rows x 15332 columns]

# %% [markdown]
# ## Probe Selection

# %% [markdown]
# Probes can index the same gene, thereby causing redundant AHBA data. Probes can be selected and condensed to resolve redundancy using the ```probe_selection``` argument.
# ```probe_selection``` contains eight total options, though the ```differential stability``` (default) option is recommended by the official [abagen docs](https://abagen.readthedocs.io/en/stable/user_guide/probes.html).

# %% [markdown]
# #### Selecting a Representative Probe

# %% [markdown]
# The following methods select a single probe from each redundant group, based off a specific selection criteria:
# - ```max_intensity```: Select the probe with the highest average expression across all samples.
# - ```max_variability```: Select the probe with the highest variance in expression across all samples.
# - ```pc_loading```: Select the probe with the highest loading value on the first principle component derived from the probe microarray expression.
# - ```corr_intensity```: Select the probe with the highest correlation to other probes across all samples, using ```max_intensity``` as a fallback in the case of exactly two probes.
# - ```corr_variance```: Select the probe with the highest correlation to other probes across all samples, using ```max_variance``` as a fallback in the case of exactly two probes.
# - ```diff_stability```: Compute the [Spearman correlation](https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient) of microarray expression values for each probe across brain regions for every pair of donors. The probe with the highest average correlation is selected.
# - ```rnaseq```: Compute the Spearman correlation of microarray expression values for each probe across brain regions with RNAseq data for the corresponding gene. Only applies to RNAseq data donors 9861 and 10021.

# %%
# Example of representative probe selection
exp_pc_load = abagen.get_expression_data(atlas['image'], probe_selection='pc_loading')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  5 13  8 20  3  6  6  3 17  7  4  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  7 41  8 21  2  1 37  5  1  7  7  4 20  7 17  4  5  6
#   5 10 22  6  6  3  4  3  2 15  3 15  7  1 18 12  5 21  5  1  1  7 44 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  1  2 11 12  6  2  9  5  9 10  6  3  6  1  5  1 11  7  9  4  2
#  10 12  7  7  3  4  2  5 31  4  9  3  2 26  1  3  1  4  1  1 11  9 16  4
#   9  8  5  8  9  4  2  2  3  2  3 11  7  6  5  3 14 11  6  7  4  1  1  8
#  47  8 12  2  2 42  4]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  7  3  2  4 10  8 11  7  6  7 15  9  3  2  2  2  2 10  6 11  9  2  6
#  11  9 10  5  1  2  7 20  7 12  3  3 29  1  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  5  4  6  4 21  5 19  5 15  8 11  8 12  4  3  3  6  5  1  8 10 13  8
#   3 10 11 12 19 10  2  1 12 28  8 14  8  3 26  9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 1  6  4  5  1 15  6 15  3 10  7 10 13 10  6  5  5  6  2  3  6  5  6 11
#   1 10 17  9 16  7  2  7 19  6 11  5  1 17  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  4  5  4  8 19  8 14  5 13  9  8 11  8  3  3  4  2  2  8  7  7 12  7
#   2 10 16 10 18  5  2  2  6 33 10  4  7  4 15  8  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %% [markdown]
# #### Collapsing Across Probes

# %% [markdown]
# An average for all probe expression values can be taken using the ```average``` parameter.

# %%
exp_pc_load = abagen.get_expression_data(atlas['image'], probe_selection='average')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  5 13  8 20  3  6  6  3 17  7  4  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  7 41  8 21  2  1 37  5  1  7  7  4 20  7 17  4  5  6
#   5 10 22  6  6  3  4  3  2 15  3 15  7  1 18 12  5 21  5  1  1  7 44 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  1  2 11 12  6  2  9  5  9 10  6  3  6  1  5  1 11  7  9  4  2
#  10 12  7  7  3  4  2  5 31  4  9  3  2 26  1  3  1  4  1  1 11  9 16  4
#   9  8  5  8  9  4  2  2  3  2  3 11  7  6  5  3 14 11  6  7  4  1  1  8
#  47  8 12  2  2 42  4]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  7  3  2  4 10  8 11  7  6  7 15  9  3  2  2  2  2 10  6 11  9  2  6
#  11  9 10  5  1  2  7 20  7 12  3  3 29  1  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  5  4  6  4 21  5 19  5 15  8 11  8 12  4  3  3  6  5  1  8 10 13  8
#   3 10 11 12 19 10  2  1 12 28  8 14  8  3 26  9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 1  6  4  5  1 15  6 15  3 10  7 10 13 10  6  5  5  6  2  3  6  5  6 11
#   1 10 17  9 16  7  2  7 19  6 11  5  1 17  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  4  5  4  8 19  8 14  5 13  9  8 11  8  3  3  4  2  2  8  7  7 12  7
#   2 10 16 10 18  5  2  2  6 33 10  4  7  4 15  8  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %% [markdown]
# ## Donor Aggregation with Probe Selection

# %% [markdown]
# By default, probe selection is performed using aggregated data across all donor samples. Donor-specific probe selection can be performed using the ```donor_probes``` argument, which takes the following three options:
# 1. ```aggregate```: Aggregate tissue samples across all donors and apply the selected ```probe_selection``` method to the aggregate sample matrix.
# 2. ```independent```: Perform the chosen ```probe_selection``` method for each donor seperately. Cannot be used with ```diff_stability```, ```rnaseq```, or ```average```.
# 3. ```common```: Perform the chosen ```probe_selection``` method for each donor, then use the most commonly-selected probe to represent each gene.

# %%
exp_cmn_rna = abagen.get_expression_data(atlas['image'], donor_probes='common', probe_selection='rnaseq')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  5 13  8 20  3  6  6  3 17  7  4  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  7 41  8 21  2  1 37  5  1  7  7  4 20  7 17  4  5  6
#   5 10 22  6  6  3  4  3  2 15  3 15  7  1 18 12  5 21  5  1  1  7 44 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  1  2 11 12  6  2  9  5  9 10  6  3  6  1  5  1 11  7  9  4  2
#  10 12  7  7  3  4  2  5 31  4  9  3  2 26  1  3  1  4  1  1 11  9 16  4
#   9  8  5  8  9  4  2  2  3  2  3 11  7  6  5  3 14 11  6  7  4  1  1  8
#  47  8 12  2  2 42  4]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  7  3  2  4 10  8 11  7  6  7 15  9  3  2  2  2  2 10  6 11  9  2  6
#  11  9 10  5  1  2  7 20  7 12  3  3 29  1  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  5  4  6  4 21  5 19  5 15  8 11  8 12  4  3  3  6  5  1  8 10 13  8
#   3 10 11 12 19 10  2  1 12 28  8 14  8  3 26  9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 1  6  4  5  1 15  6 15  3 10  7 10 13 10  6  5  5  6  2  3  6  5  6 11
#   1 10 17  9 16  7  2  7 19  6 11  5  1 17  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  4  5  4  8 19  8 14  5 13  9  8 11  8  3  3  4  2  2  8  7  7 12  7
#   2 10 16 10 18  5  2  2  6 33 10  4  7  4 15  8  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %% [markdown]
# ## Data Normalization

# %% [markdown]
# The abagen library supports nine options for dataset normalization, though the default ```scaled_robust_sigmoid``` option is recommended by the official [abagen docs](https://abagen.readthedocs.io/en/stable/user_guide/normalization.html). Data normalization options are as follows:
# 1. Centering: ```center```
# 2. Z-score: ```zscore```
# 3. Min-max: ```minmax```
# 4. Sigmoid: ```sigmoid```
# 5. Scaled Sigmoid: ```scaled_sigmoid```
# 6. Scaled Sigmoid Quantiles: ```scaled_sigmoid_quantiles```
# 7. Robust Sigmoid: ```robust_sigmoid```
# 8. Scaled Robust Sigmoid: ```scaled_robust_sigmoid```
# 9. Mixed Sigmoid: ```mixed_sigmoid```
#
# Providing a value of ```None``` prevents data normalization.
#
# Normalization can be accomplished in two directions:
# 1. Each sample can be normalized across all genes (```gene_norm```).
# 2. Each sample can be normalized across all samples (```sample_norm```).

# %%
# Use z-score normalization across all samples
exp_norm_zscore = abagen.get_expression_data(atlas['image'], sample_norm='zscore')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 5  4  6  2  5 13  8 20  3  6  6  3 17  7  4  4  5  1  9  5 17  4  1  8
#  20  7 15  9  2  3  7 41  8 21  2  1 37  5  1  7  7  4 20  7 17  4  5  6
#   5 10 22  6  6  3  4  3  2 15  3 15  7  1 18 12  5 21  5  1  1  7 44 10
#  13  2 35]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  1  7  1  2 11 12  6  2  9  5  9 10  6  3  6  1  5  1 11  7  9  4  2
#  10 12  7  7  3  4  2  5 31  4  9  3  2 26  1  3  1  4  1  1 11  9 16  4
#   9  8  5  8  9  4  2  2  3  2  3 11  7  6  5  3 14 11  6  7  4  1  1  8
#  47  8 12  2  2 42  4]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  7  3  2  4 10  8 11  7  6  7 15  9  3  2  2  2  2 10  6 11  9  2  6
#  11  9 10  5  1  2  7 20  7 12  3  3 29  1  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 3  5  4  6  4 21  5 19  5 15  8 11  8 12  4  3  3  6  5  1  8 10 13  8
#   3 10 11 12 19 10  2  1 12 28  8 14  8  3 26  9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 1  6  4  5  1 15  6 15  3 10  7 10 13 10  6  5  5  6  2  3  6  5  6 11
#   1 10 17  9 16  7  2  7 19  6 11  5  1 17  6]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2  4  5  4  8 19  8 14  5 13  9  8 11  8  3  3  4  2  2  8  7  7 12  7
#   2 10 16 10 18  5  2  2  6 33 10  4  7  4 15  8  2]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %% [markdown]
# ## Reporting

# %% [markdown]
# Based on the selected parameters, abagen can generate a report that details each processing step done to the AHBA dataset.

# %%
report = reporting.Report(atlas['image'], atlas['info']).gen_report()
print(report)
# Out:
# Regional microarry expression data were obtained from 6 post-mortem brains (1 female, ages 24.0--57.0, 42.50 +/- 13.38) provided by the Allen Human Brain Atlas (AHBA, https://human.brain-map.org; [H2012N]). Data were processed with the abagen toolbox (version 0.1.4+15.gdc4a007; https://github.com/rmarkello/abagen; [M2021B]) using a 82-region volumetric atlas, independently aligned to each donor's native MRI space.
#
# First, microarray probes were reannotated using data provided by [A2019N]; probes not matched to a valid Entrez ID were discarded. Next, probes were filtered based on their expression intensity relative to background noise [Q2002N], such that probes with intensity less than the background in >=50.00% of samples across donors were discarded . When multiple probes indexed the expression of the same gene, we selected and used the probe with the most consistent pattern of regional variation across donors (i.e., differential stability; [H2015N]), calculated with:
#
# $$ \Delta_{{S}}(p) = \frac{{1}}{{\binom{{N}}{{2}}}} \, \sum_{{i=1}}^{{N-1}} \sum_{{j=i+1}}^{{N}} \rho[B_{{i}}(p), B_{{j}}(p)] $$
#
# where $ \rho $ is Spearman's rank correlation of the expression of a single probe, p, across regions in two donors $B_{{i}}$ and $B_{{j}}$, and N is the total number of donors. Here, regions correspond to the structural designations provided in the ontology from the AHBA.
#
# Samples were assigned to brain regions in the provided atlas if their native voxel coordinates were within 2 mm of a given parcel. To reduce the potential for misassignment, sample-to-region matching was constrained by hemisphere and gross structural divisions (i.e., cortex, subcortex/brainstem, and cerebellum, such that e.g., a sample in the left cortex could only be assigned to an atlas parcel in the left cortex; [A2019N]). All tissue samples not assigned to a brain region in the provided atlas were discarded.
#
# Inter-subject variation was addressed by normalizing tissue sample expression values across genes using a robust sigmoid function [F2013J]:
#
# $$ x_{{norm}} = \frac{{1}}{{1 + \exp(-\frac{{(x-\langle x \rangle)}} {{\text{{IQR}}_{{x}}}})}} $$
#
# where $\langle x \rangle$ is the median and $\text{{IQR}}_{{x}}$ is the normalized interquartile range of the expression of a single tissue sample across genes. Normalized expression values were then rescaled to the unit interval:
#
# $$ x_{{scaled}} = \frac{{x_{{norm}} - \min(x_{{norm}})}} {{\max(x_{{norm}}) - \min(x_{{norm}})}} $$
#
# Gene expression values were then normalized across tissue samples using an identical procedure. Samples assigned to the same brain region were averaged separately for each donor and then across donors, yielding a regional expression matrix.
#
# REFERENCES
# ----------
# [A2019N]: Arnatkevic̆iūtė, A., Fulcher, B. D., & Fornito, A. (2019). A practical guide to linking brain-wide gene expression and neuroimaging data. Neuroimage, 189, 353-367.
# [F2013J]: Fulcher, B. D., Little, M. A., & Jones, N. S. (2013). Highly comparative time-series analysis: the empirical structure of time series and their methods. Journal of the Royal Society Interface, 10(83), 20130048.
# [H2012N]: Hawrylycz, M. J., Lein, E. S., Guillozet-Bongaarts, A. L., Shen, E. H., Ng, L., Miller, J. A., ... & Jones, A. R. (2012). An anatomically comprehensive atlas of the adult human brain transcriptome. Nature, 489(7416), 391-399.
# [H2015N]: Hawrylycz, M., Miller, J. A., Menon, V., Feng, D., Dolbeare, T., Guillozet-Bongaarts, A. L., ... & Lein, E. (2015). Canonical genetic signatures of the adult human brain. Nature Neuroscience, 18(12), 1832.
# [M2021B]: Markello, R.D., Arnatkevic̆iūtė, A., Poline, J-B., Fulcher, B. D., Fornito, A., & Misic, B. (2021). Standardizing workflows in imaging transcriptomics with the abagen toolbox. Biorxiv.
# [Q2002N]: Quackenbush, J. (2002). Microarray data normalization and transformation. Nature Genetics, 32(4), 496-501.

# %% [markdown]
# ## Probe Data

# %%
files = abagen.fetch_microarray(donors='all', data_dir='./data')

# %%
# Each donor file contains a probe count of 352,152
for donor in files:
    print(f"Donor {donor} probe count: {abagen.io.read_probes(files[donor]['probes']).size}")
# Out:
# Donor 9861 probe count: 352152
# Donor 10021 probe count: 352152
# Donor 12876 probe count: 352152
# Donor 14380 probe count: 352152
# Donor 15496 probe count: 352152
# Donor 15697 probe count: 352152

# %% [markdown]
# ## PCA & Clustering Analysis

# %% [markdown]
# The following section performs dimensionality reduction using the region labels as features. For feature reduction with respect to the genes, see the section titled 'Gene Expression PCA & Clustering'. See the following [365 Data Science](https://365datascience.com/tutorials/python-tutorials/pca-k-means/) guide for more information regarding PCA-based clustering.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ### Brain Region PCA & Clustering

# %%
atlas = abagen.fetch_desikan_killiany()
expression = abagen.get_expression_data(atlas['image'], atlas['info'], donors=['9861', '10021'], missing='centroids')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[  8   4   5   2   4  15   8  17   3   2   6   5   5  13   3   4   7   3
#    2   9   5  14   1   2   6  15   6  20   5   2   2   5  28   7  17   6
#    1  38   6   2   3   2   1   3  19   4  22   4   5   9   5   8  18   3
#    7   2   3   4   1  16   5  14   4   2  16  13   3  16   4   1   8  32
#    7  14   7   1  34   1 148]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[  2   1   3   3   2   8  10   8   1   8   6   7   6   7   2   7   2   4
#    2   5   6  10   4   5  10  16   9   6   4   4   4   3  29   4   9   2
#    4  26   1   4   2   6   1   2  11   7  15   2   5   6   4  11  10   4
#    4   3   2   5   2  13   7   5   6   3  10  10   6   6   3   6  33   9
#    9   4   3  38   5 159]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %%
# Plot two brain regions with respect to one another
# Each data point corresponds to a parcellation
plt.figure(figsize=(12, 9))
plt.scatter(expression.iloc[1], expression.iloc[0])
plt.xlabel('Brain Region 2')
plt.ylabel('Brain Region 1')
# Out:
# Text(0, 0.5, 'Brain Region 1')

# %% [markdown]
# #### Data Preprocessing

# %%
# In PCA, the columns represent the features, so we need to take the transpose of expression
expression_t = expression.transpose()
expression_t
# Out:
# label              1         2         3         4         5         6   \
# gene_symbol
# A1BG         0.454583  0.706707  0.566528  0.212931  0.642248  0.600414
# A1BG-AS1     0.658482  0.671063  0.675010  0.576003  0.593896  0.684290
# A2M          0.277650  0.406233  0.437712  0.357136  0.542412  0.410224
# A2ML1        0.357625  0.582556  0.468049  0.438805  0.394510  0.475946
# A3GALT2      0.347462  0.267532  0.425430  0.373285  0.312705  0.382731
# ...               ...       ...       ...       ...       ...       ...
# ZXDC         0.308915  0.246902  0.332620  0.403771  0.527073  0.484706
# ZYG11B       0.704540  0.672475  0.755129  0.738577  0.680514  0.707230
# ZYX          0.629293  0.601816  0.778413  0.770315  0.388747  0.556816
# ZZEF1        0.621094  0.431178  0.374840  0.727547  0.360202  0.484526
# ZZZ3         0.527410  0.598830  0.520263  0.394037  0.670559  0.557113
#
# label              7         8         9         10  ...        74        75  \
# gene_symbol                                          ...
# A1BG         0.438406  0.603297  0.358863  0.409077  ...  0.505040  0.650363
# A1BG-AS1     0.624603  0.687409  0.678395  0.671024  ...  0.482217  0.682945
# A2M          0.294762  0.316882  0.556220  0.320672  ...  0.551028  0.504662
# A2ML1        0.473719  0.445315  0.293247  0.352642  ...  0.914644  0.451738
# A3GALT2      0.285532  0.336338  0.355594  0.332712  ...  0.749712  0.306623
# ...               ...       ...       ...       ...  ...       ...       ...
# ZXDC         0.443622  0.412888  0.348760  0.433787  ...  0.653891  0.393357
# ZYG11B       0.703572  0.679432  0.726794  0.747905  ...  0.741746  0.688159
# ZYX          0.647601  0.605544  0.831253  0.777592  ...  0.791455  0.573792
# ZZEF1        0.578507  0.466739  0.700095  0.610455  ...  0.520935  0.422632
# ZZZ3         0.457222  0.533581  0.471333  0.530979  ...  0.339419  0.539313
#
# label              76        77        78        79        80        81  \
# gene_symbol
# A1BG         0.394149  0.615253  0.702853  0.797560  0.743788  0.389645
# A1BG-AS1     0.222998  0.321505  0.454018  0.222321  0.410607  0.276079
# A2M          0.666740  0.693760  0.580753  0.828974  0.453053  0.472205
# A2ML1        0.572416  0.693755  0.565157  0.535699  0.549809  0.629451
# A3GALT2      0.590055  0.623734  0.433760  0.365279  0.458905  0.648575
# ...               ...       ...       ...       ...       ...       ...
# ZXDC         0.555390  0.695097  0.641207  0.777148  0.542317  0.549538
# ZYG11B       0.416941  0.277801  0.311684  0.266571  0.559660  0.374396
# ZYX          0.358159  0.219237  0.349651  0.409345  0.184873  0.279621
# ZZEF1        0.474534  0.338046  0.521915  0.570861  0.439499  0.482638
# ZZZ3         0.547460  0.419327  0.594733  0.769341  0.803298  0.406441
#
# label              82        83
# gene_symbol
# A1BG         0.834718  0.460944
# A1BG-AS1     0.606113  0.198541
# A2M          0.341910  0.763409
# A2ML1        0.516733  0.526759
# A3GALT2      0.511969  0.601813
# ...               ...       ...
# ZXDC         0.626717  0.551906
# ZYG11B       0.344730  0.332730
# ZYX          0.199706  0.443646
# ZZEF1        0.471017  0.615642
# ZZZ3         0.765191  0.484134
#
# [15329 rows x 83 columns]

# %%
scaler = StandardScaler()
expression_std = scaler.fit_transform(expression_t)
expression_std.shape
# Out:
# (15329, 83)

# %% [markdown]
# #### PCA

# %%
pca = PCA()
pca.fit(expression_t)
# Determines how much variance among genes is explained by each brain region
pca.explained_variance_ratio_
# Out:
# array([5.04752646e-01, 1.11635518e-01, 8.43819271e-02, 5.44156105e-02,
#        3.44836261e-02, 2.92833526e-02, 2.03815421e-02, 1.54939354e-02,
#        1.17820501e-02, 1.13633612e-02, 1.03916032e-02, 9.47988123e-03,
#        8.53948220e-03, 7.73335478e-03, 6.43417779e-03, 5.92274318e-03,
#        5.05365320e-03, 4.37845873e-03, 4.22520217e-03, 3.69971952e-03,
#        3.63325494e-03, 3.03555384e-03, 2.77414869e-03, 2.57219279e-03,
#        2.43591200e-03, 2.35545018e-03, 2.25585443e-03, 2.00558712e-03,
#        1.98096233e-03, 1.73239328e-03, 1.63928333e-03, 1.56997276e-03,
#        1.52199273e-03, 1.40501556e-03, 1.36428018e-03, 1.26826020e-03,
#        1.18679402e-03, 1.06820363e-03, 1.02000838e-03, 9.56728649e-04,
#        9.30553594e-04, 8.72829108e-04, 8.34006105e-04, 7.91557390e-04,
#        7.58271406e-04, 7.32430085e-04, 7.16938699e-04, 6.66676197e-04,
#        6.65417340e-04, 6.21865234e-04, 5.88715746e-04, 5.48665258e-04,
#        5.35552413e-04, 5.11587525e-04, 5.00213064e-04, 4.81196421e-04,
#        4.48682603e-04, 4.44458406e-04, 4.21295865e-04, 3.98111217e-04,
#        3.89663427e-04, 3.79550321e-04, 3.57241690e-04, 3.49169476e-04,
#        3.40638507e-04, 3.18411584e-04, 3.08643539e-04, 2.98526654e-04,
#        2.80885089e-04, 2.65974386e-04, 2.63316087e-04, 2.55263760e-04,
#        2.43520138e-04, 2.35707484e-04, 2.21113667e-04, 2.13992816e-04,
#        2.00869873e-04, 1.92082327e-04, 1.84374881e-04, 1.75829903e-04,
#        1.68813608e-04, 1.48192371e-04, 1.25500928e-04])

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1, 84), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Explained Variance by Components (Brain Regions)')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance (Cumulative)')
# Out:
# Text(0, 0.5, 'Explained Variance (Cumulative)')

# %%
# We'd like to capture ~80% of our variance, so we'll keep six components
pca = PCA(n_components = 6)
pca.fit(expression_std)
scores_pca = pca.transform(expression_std)

# Fit K-Means using PCA data
wcss = []

N_CLUSTERS = 20
for i in range(1, N_CLUSTERS + 1):
    kmeans_pca = KMeans(n_clusters = i, init = 'k-means++', random_state = 21)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, N_CLUSTERS + 1), wcss, marker = 'o', linestyle = '--')

# %%
# Given the graph above, we'd like to keep three clusters (see Elbow Method for K-means Clustering)
N_CLUSTERS = 10
kmeans_pca = KMeans(n_clusters = N_CLUSTERS, init='k-means++', random_state = 21)
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=10, random_state=21)

# %%
# Create a new data frame with the original features and add the PCA scores and assigned clusters
exp_pca_kmeans = pd.concat([expression_t.reset_index(drop = True), pd.DataFrame(scores_pca)], axis = 1)
labels = [i for i in range(0, len(expression_t.columns))] + ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5', 'Component 6']
exp_pca_kmeans.columns = labels

# Add the PCA K-means Clustering labels
exp_pca_kmeans['Expression K-Means PCA'] = kmeans_pca.labels_
exp_pca_kmeans
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.454583  0.706707  0.566528  0.212931  0.642248  0.600414  0.438406
# 1      0.658482  0.671063  0.675010  0.576003  0.593896  0.684290  0.624603
# 2      0.277650  0.406233  0.437712  0.357136  0.542412  0.410224  0.294762
# 3      0.357625  0.582556  0.468049  0.438805  0.394510  0.475946  0.473719
# 4      0.347462  0.267532  0.425430  0.373285  0.312705  0.382731  0.285532
# ...         ...       ...       ...       ...       ...       ...       ...
# 15324  0.308915  0.246902  0.332620  0.403771  0.527073  0.484706  0.443622
# 15325  0.704540  0.672475  0.755129  0.738577  0.680514  0.707230  0.703572
# 15326  0.629293  0.601816  0.778413  0.770315  0.388747  0.556816  0.647601
# 15327  0.621094  0.431178  0.374840  0.727547  0.360202  0.484526  0.578507
# 15328  0.527410  0.598830  0.520263  0.394037  0.670559  0.557113  0.457222
#
#               7         8         9  ...        80        81        82  \
# 0      0.603297  0.358863  0.409077  ...  0.389645  0.834718  0.460944
# 1      0.687409  0.678395  0.671024  ...  0.276079  0.606113  0.198541
# 2      0.316882  0.556220  0.320672  ...  0.472205  0.341910  0.763409
# 3      0.445315  0.293247  0.352642  ...  0.629451  0.516733  0.526759
# 4      0.336338  0.355594  0.332712  ...  0.648575  0.511969  0.601813
# ...         ...       ...       ...  ...       ...       ...       ...
# 15324  0.412888  0.348760  0.433787  ...  0.549538  0.626717  0.551906
# 15325  0.679432  0.726794  0.747905  ...  0.374396  0.344730  0.332730
# 15326  0.605544  0.831253  0.777592  ...  0.279621  0.199706  0.443646
# 15327  0.466739  0.700095  0.610455  ...  0.482638  0.471017  0.615642
# 15328  0.533581  0.471333  0.530979  ...  0.406441  0.765191  0.484134
#
#        Component 1  Component 2  Component 3  Component 4  Component 5  \
# 0         0.358435    -6.454008    -0.572388     0.834014     0.487948
# 1        -9.416227    -0.756589     1.641521    -0.112737    -0.068235
# 2         7.285241    -1.557346     0.587037     2.711761     1.166816
# 3         4.565809     0.019292    -1.494406    -0.256299     1.959844
# 4         7.368270     1.414843     1.229175    -0.136939     2.128558
# ...            ...          ...          ...          ...          ...
# 15324     5.161481    -2.304970    -2.471716     0.801508     2.328850
# 15325   -13.201411     0.708159     1.436425     0.591819     1.093563
# 15326    -9.457143     6.195765     0.300870     2.132897     0.964220
# 15327     2.003910     4.251002    -2.280726     0.232073     0.434106
# 15328     1.344918    -3.349979    -0.630859    -0.006217    -1.751693
#
#        Component 6  Expression K-Means PCA
# 0        -2.289595                       9
# 1        -0.358266                       4
# 2         0.487159                       3
# 3         1.415576                       3
# 4         1.525151                       1
# ...            ...                     ...
# 15324     0.215395                       3
# 15325     0.152711                       2
# 15326    -0.297017                       0
# 15327     1.868266                       8
# 15328    -2.844154                       9
#
# [15329 rows x 90 columns]

# %%
exp_pca_kmeans['Expression'] = exp_pca_kmeans['Expression K-Means PCA'].map({0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth', 6:'seventh', 7:'eighth', 8:'ninth', 9:'tenth'})

# %%
# Plot data using the two PCA components with largest variance
x_axis = exp_pca_kmeans['Component 1']
y_axis = exp_pca_kmeans['Component 2']
plt.figure(figsize=(10, 8))
sns.scatterplot(x = x_axis, y = y_axis, hue = exp_pca_kmeans['Expression'])
plt.title('Gene Clusters by PCA Components')
plt.show()

# %% [markdown]
# ### Gene Expression PCA & Clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
atlas = abagen.fetch_desikan_killiany()
expression = abagen.get_expression_data(atlas['image'], atlas['info'], donors=['9861', '10021'], missing='centroids')
# Out:
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\probes_.py:147: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   return io.read_microarray(microarray).groupby(sid, axis=1).mean()
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[  8   4   5   2   4  15   8  17   3   2   6   5   5  13   3   4   7   3
#    2   9   5  14   1   2   6  15   6  20   5   2   2   5  28   7  17   6
#    1  38   6   2   3   2   1   3  19   4  22   4   5   9   5   8  18   3
#    7   2   3   4   1  16   5  14   4   2  16  13   3  16   4   1   8  32
#    7  14   7   1  34   1 148]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\allen.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[  2   1   3   3   2   8  10   8   1   8   6   7   6   7   2   7   2   4
#    2   5   6  10   4   5  10  16   9   6   4   4   4   3  29   4   9   2
#    4  26   1   4   2   6   1   2  11   7  15   2   5   6   4  11  10   4
#    4   3   2   5   2  13   7   5   6   3  10  10   6   6   3   6  33   9
#    9   4   3  38   5 159]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   counts.loc[labs, subj] = num
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:405: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray.groupby('label').aggregate(metric),
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:404: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   gene_by_label = pd.concat([
# c:\Users\umber\OneDrive\Documents\Research\minds\ahba\Lib\site-packages\abagen\samples_.py:481: FutureWarning: The provided callable <function mean at 0x00000248FE7A2F20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   microarray = pd.concat(microarray).groupby('label').aggregate(metric)

# %%
expression
# Out:
# gene_symbol      A1BG  A1BG-AS1       A2M     A2ML1   A3GALT2    A4GALT  \
# label
# 1            0.454583  0.658482  0.277650  0.357625  0.347462  0.497014
# 2            0.706707  0.671063  0.406233  0.582556  0.267532  0.256723
# 3            0.566528  0.675010  0.437712  0.468049  0.425430  0.446146
# 4            0.212931  0.576003  0.357136  0.438805  0.373285  0.268619
# 5            0.642248  0.593896  0.542412  0.394510  0.312705  0.625741
# ...               ...       ...       ...       ...       ...       ...
# 79           0.797560  0.222321  0.828974  0.535699  0.365279  0.595596
# 80           0.743788  0.410607  0.453053  0.549809  0.458905  0.242426
# 81           0.389645  0.276079  0.472205  0.629451  0.648575  0.561573
# 82           0.834718  0.606113  0.341910  0.516733  0.511969  0.204136
# 83           0.460944  0.198541  0.763409  0.526759  0.601813  0.560663
#
# gene_symbol      AAAS      AACS   AADACL3     AADAT  ...      ZW10    ZWILCH  \
# label                                                ...
# 1            0.349346  0.724353  0.367414  0.669540  ...  0.468521  0.597330
# 2            0.484846  0.812316  0.459672  0.597053  ...  0.402174  0.655087
# 3            0.596285  0.841651  0.419038  0.627651  ...  0.634589  0.636558
# 4            0.589126  0.727150  0.526787  0.710701  ...  0.562480  0.607929
# 5            0.451634  0.768109  0.341174  0.590407  ...  0.347714  0.595186
# ...               ...       ...       ...       ...  ...       ...       ...
# 79           0.628648  0.187954  0.521689  0.653557  ...  0.629069  0.265946
# 80           0.256931  0.348701  0.535722  0.721475  ...  0.639309  0.407482
# 81           0.339787  0.517898  0.725916  0.225080  ...  0.367886  0.380907
# 82           0.207806  0.483309  0.554375  0.579146  ...  0.222955  0.758421
# 83           0.591394  0.332751  0.708555  0.292948  ...  0.516295  0.309045
#
# gene_symbol     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11B       ZYX  \
# label
# 1            0.590565  0.446169  0.552484  0.308915  0.704540  0.629293
# 2            0.408689  0.540830  0.458972  0.246902  0.672475  0.601816
# 3            0.503855  0.402906  0.441906  0.332620  0.755129  0.778413
# 4            0.506795  0.385504  0.531667  0.403771  0.738577  0.770315
# 5            0.673300  0.444794  0.362994  0.527073  0.680514  0.388747
# ...               ...       ...       ...       ...       ...       ...
# 79           0.334673  0.547770  0.439937  0.777148  0.266571  0.409345
# 80           0.713832  0.657642  0.720752  0.542317  0.559660  0.184873
# 81           0.641801  0.627132  0.474090  0.549538  0.374396  0.279621
# 82           0.567911  0.773956  0.633343  0.626717  0.344730  0.199706
# 83           0.338550  0.558695  0.557970  0.551906  0.332730  0.443646
#
# gene_symbol     ZZEF1      ZZZ3
# label
# 1            0.621094  0.527410
# 2            0.431178  0.598830
# 3            0.374840  0.520263
# 4            0.727547  0.394037
# 5            0.360202  0.670559
# ...               ...       ...
# 79           0.570861  0.769341
# 80           0.439499  0.803298
# 81           0.482638  0.406441
# 82           0.471017  0.765191
# 83           0.615642  0.484134
#
# [83 rows x 15329 columns]

# %%
scaler = StandardScaler()
expression_std = scaler.fit_transform(expression)
expression_std.shape
# Out:
# (83, 15329)

# %%
pca = PCA()
pca.fit(expression)
# Determines how much variance among brain regions is expressed by the 83 most variable genes,
# since n_components == min(n_samples, n_features)
pca.explained_variance_ratio_
# Out:
# array([3.98626754e-01, 1.28879144e-01, 8.18475934e-02, 7.23374601e-02,
#        4.06963516e-02, 3.76329276e-02, 2.83063729e-02, 2.23945993e-02,
#        1.61396492e-02, 1.44230951e-02, 1.32740716e-02, 1.19680399e-02,
#        1.08622947e-02, 9.67732461e-03, 8.20966991e-03, 7.42867986e-03,
#        6.28301094e-03, 5.91602228e-03, 5.64811065e-03, 5.09275979e-03,
#        4.24937648e-03, 4.19927402e-03, 3.65342283e-03, 3.45147629e-03,
#        3.38546616e-03, 3.14542997e-03, 2.96481721e-03, 2.76183784e-03,
#        2.39616331e-03, 2.27800535e-03, 2.19964166e-03, 2.14292190e-03,
#        2.05832220e-03, 1.93908447e-03, 1.87145169e-03, 1.64428234e-03,
#        1.53620335e-03, 1.47475435e-03, 1.38338518e-03, 1.28742629e-03,
#        1.26164964e-03, 1.16657715e-03, 1.09620385e-03, 1.04819709e-03,
#        1.01440593e-03, 9.94609554e-04, 9.36760467e-04, 9.19910717e-04,
#        8.71087048e-04, 8.23250490e-04, 7.67878574e-04, 7.42777044e-04,
#        7.06491612e-04, 6.92459857e-04, 6.69332624e-04, 6.43656176e-04,
#        6.23035795e-04, 5.84402204e-04, 5.53658227e-04, 5.38314175e-04,
#        5.35276745e-04, 4.95241939e-04, 4.82767586e-04, 4.70514766e-04,
#        4.49701065e-04, 4.26675557e-04, 4.13048505e-04, 3.88190684e-04,
#        3.68283350e-04, 3.63950849e-04, 3.53380238e-04, 3.36689964e-04,
#        3.25974448e-04, 3.11770550e-04, 2.96883012e-04, 2.78146897e-04,
#        2.65348502e-04, 2.57570416e-04, 2.43125241e-04, 2.37410274e-04,
#        2.05090933e-04, 1.73625227e-04, 1.26517010e-30])

# %%
plt.figure(figsize=(10,8))
plt.plot(range(0, 83), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Explained Variance by Components (Genes)')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance (Cumulative)')
# Out:
# Text(0, 0.5, 'Explained Variance (Cumulative)')

# %%
# For ~80% of our variance, we'll keep eight components
pca_80 = PCA(n_components = 8)
pca_80.fit(expression_std)
# For ~50% of our variance, we'll keep two components
pca_50 = PCA(n_components = 2)
pca_50.fit(expression_std)
# For ~40% of our variance, we'll keep one component
pca_40 = PCA(n_components = 1)
pca_40.fit(expression_std)

scores_pca_80 = pca_80.transform(expression_std)
scores_pca_50 = pca_50.transform(expression_std)
scores_pca_40 = pca_40.transform(expression_std)

# Fit K-Means using PCA data
wcss_80 = []
wcss_50 = []
wcss_40 = []

N_CLUSTERS = 20
for i in range(1, N_CLUSTERS + 1):
    kmeans_pca_80 = KMeans(n_clusters = i, init = 'k-means++', random_state = 64)
    kmeans_pca_80.fit(scores_pca_80)
    wcss_80.append(kmeans_pca_80.inertia_)

    kmeans_pca_50 = KMeans(n_clusters = i, init = 'k-means++', random_state = 64)
    kmeans_pca_50.fit(scores_pca_50)
    wcss_50.append(kmeans_pca_50.inertia_)

    kmeans_pca_40 = KMeans(n_clusters = i, init = 'k-means++', random_state = 64)
    kmeans_pca_40.fit(scores_pca_40)
    wcss_40.append(kmeans_pca_40.inertia_)

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, N_CLUSTERS + 1), wcss_80, marker = 'o', linestyle = '--')

# %%
N_CLUSTERS_80 = 10
kmeans_pca_80 = KMeans(n_clusters = N_CLUSTERS_80, init='k-means++', random_state = 21)
kmeans_pca_80.fit(scores_pca_80)
# Out:
# KMeans(n_clusters=10, random_state=21)

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, N_CLUSTERS + 1), wcss_50, marker = 'o', linestyle = '--')

# %%
N_CLUSTERS_50 = 10
kmeans_pca_50 = KMeans(n_clusters = N_CLUSTERS_50, init='k-means++', random_state = 21)
kmeans_pca_50.fit(scores_pca_50)
# Out:
# KMeans(n_clusters=10, random_state=21)

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, N_CLUSTERS + 1), wcss_40, marker = 'o', linestyle = '--')

# %%
N_CLUSTERS_40 = 7
kmeans_pca_40 = KMeans(n_clusters = N_CLUSTERS_40, init='k-means++', random_state = 21)
kmeans_pca_40.fit(scores_pca_40)
# Out:
# KMeans(n_clusters=7, random_state=21)

# %%
exp_pca_kmeans_80 = pd.concat([expression.reset_index(drop = True), pd.DataFrame(scores_pca_80)], axis = 1)
labels = [i for i in range(0, len(expression.columns))] + ['Component 1', 'Component 2', 'Component 3', 'Component 4', 'Component 5', 'Component 6', 'Component 7', 'Component 8']
exp_pca_kmeans_80.columns = labels

# Add the PCA K-means Clustering labels
exp_pca_kmeans_80['Expression K-Means PCA'] = kmeans_pca_80.labels_
exp_pca_kmeans_80

exp_pca_kmeans_80['Expression'] = exp_pca_kmeans_80['Expression K-Means PCA'].map({0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth', 6:'seventh', 7:'eighth', 8:'ninth', 9:'tenth'})
exp_pca_kmeans_80
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.454583  0.658482  0.277650  0.357625  0.347462  0.497014  0.349346
# 1   0.706707  0.671063  0.406233  0.582556  0.267532  0.256723  0.484846
# 2   0.566528  0.675010  0.437712  0.468049  0.425430  0.446146  0.596285
# 3   0.212931  0.576003  0.357136  0.438805  0.373285  0.268619  0.589126
# 4   0.642248  0.593896  0.542412  0.394510  0.312705  0.625741  0.451634
# ..       ...       ...       ...       ...       ...       ...       ...
# 78  0.797560  0.222321  0.828974  0.535699  0.365279  0.595596  0.628648
# 79  0.743788  0.410607  0.453053  0.549809  0.458905  0.242426  0.256931
# 80  0.389645  0.276079  0.472205  0.629451  0.648575  0.561573  0.339787
# 81  0.834718  0.606113  0.341910  0.516733  0.511969  0.204136  0.207806
# 82  0.460944  0.198541  0.763409  0.526759  0.601813  0.560663  0.591394
#
#            7         8         9  ...  Component 1  Component 2  Component 3  \
# 0   0.724353  0.367414  0.669540  ...   -46.456043    30.467533    37.173553
# 1   0.812316  0.459672  0.597053  ...   -33.279021   -30.969575    19.204282
# 2   0.841651  0.419038  0.627651  ...   -50.369155    -8.426313   -31.412072
# 3   0.727150  0.526787  0.710701  ...   -30.416474   102.558310    29.041958
# 4   0.768109  0.341174  0.590407  ...     8.379403   -71.893118     3.736231
# ..       ...       ...       ...  ...          ...          ...          ...
# 78  0.187954  0.521689  0.653557  ...   207.782714   -16.902845   -86.494127
# 79  0.348701  0.535722  0.721475  ...    87.203198   -62.216471   118.616497
# 80  0.517898  0.725916  0.225080  ...   112.844774    31.419288    27.608639
# 81  0.483309  0.554375  0.579146  ...    84.992897    12.211219    88.505832
# 82  0.332751  0.708555  0.292948  ...   191.324003    37.750412  -102.817242
#
#     Component 4  Component 5  Component 6  Component 7  Component 8  \
# 0    -14.522337    23.828087   -26.874114     4.494145    23.727713
# 1      3.142296    50.778957     6.410476    -4.633170     1.249649
# 2     -8.936988    20.627783     0.819565   -38.589512     2.777369
# 3    -18.340758    -8.825398    -2.784007    13.916952   -23.554551
# 4     23.977963    21.956610    16.204141    41.764465    -8.707895
# ..          ...          ...          ...          ...          ...
# 78   -95.341239    62.873752    -3.598203    23.190768    -9.516852
# 79   -81.501633   -10.908794   -39.753600   -17.186472   -35.981632
# 80   137.268696   -45.343887    -9.352319   -11.785251   -19.001477
# 81    90.033273    36.874070   -54.932393    31.872867    84.898110
# 82    47.034537    27.420775   -73.477035    -5.215137    -9.444786
#
#     Expression K-Means PCA  Expression
# 0                        6     seventh
# 1                        1      second
# 2                        1      second
# 3                        7      eighth
# 4                        0       first
# ..                     ...         ...
# 78                       2       third
# 79                       5       sixth
# 80                       3      fourth
# 81                       3      fourth
# 82                       4       fifth
#
# [83 rows x 15339 columns]

# %%
exp_pca_kmeans_50 = pd.concat([expression.reset_index(drop = True), pd.DataFrame(scores_pca_50)], axis = 1)
labels = [i for i in range(0, len(expression.columns))] + ['Component 1', 'Component 2']
exp_pca_kmeans_50.columns = labels

# Add the PCA K-means Clustering labels
exp_pca_kmeans_50['Expression K-Means PCA'] = kmeans_pca_50.labels_
exp_pca_kmeans_50

exp_pca_kmeans_50['Expression'] = exp_pca_kmeans_50['Expression K-Means PCA'].map({0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth', 6:'seventh', 7:'eighth', 8:'ninth', 9:'tenth'})
exp_pca_kmeans_50
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.454583  0.658482  0.277650  0.357625  0.347462  0.497014  0.349346
# 1   0.706707  0.671063  0.406233  0.582556  0.267532  0.256723  0.484846
# 2   0.566528  0.675010  0.437712  0.468049  0.425430  0.446146  0.596285
# 3   0.212931  0.576003  0.357136  0.438805  0.373285  0.268619  0.589126
# 4   0.642248  0.593896  0.542412  0.394510  0.312705  0.625741  0.451634
# ..       ...       ...       ...       ...       ...       ...       ...
# 78  0.797560  0.222321  0.828974  0.535699  0.365279  0.595596  0.628648
# 79  0.743788  0.410607  0.453053  0.549809  0.458905  0.242426  0.256931
# 80  0.389645  0.276079  0.472205  0.629451  0.648575  0.561573  0.339787
# 81  0.834718  0.606113  0.341910  0.516733  0.511969  0.204136  0.207806
# 82  0.460944  0.198541  0.763409  0.526759  0.601813  0.560663  0.591394
#
#            7         8         9  ...     15323     15324     15325     15326  \
# 0   0.724353  0.367414  0.669540  ...  0.552484  0.308915  0.704540  0.629293
# 1   0.812316  0.459672  0.597053  ...  0.458972  0.246902  0.672475  0.601816
# 2   0.841651  0.419038  0.627651  ...  0.441906  0.332620  0.755129  0.778413
# 3   0.727150  0.526787  0.710701  ...  0.531667  0.403771  0.738577  0.770315
# 4   0.768109  0.341174  0.590407  ...  0.362994  0.527073  0.680514  0.388747
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 78  0.187954  0.521689  0.653557  ...  0.439937  0.777148  0.266571  0.409345
# 79  0.348701  0.535722  0.721475  ...  0.720752  0.542317  0.559660  0.184873
# 80  0.517898  0.725916  0.225080  ...  0.474090  0.549538  0.374396  0.279621
# 81  0.483309  0.554375  0.579146  ...  0.633343  0.626717  0.344730  0.199706
# 82  0.332751  0.708555  0.292948  ...  0.557970  0.551906  0.332730  0.443646
#
#        15327     15328  Component 1  Component 2  Expression K-Means PCA  \
# 0   0.621094  0.527410   -46.456043    30.467533                       9
# 1   0.431178  0.598830   -33.279021   -30.969576                       1
# 2   0.374840  0.520263   -50.369155    -8.426313                       1
# 3   0.727547  0.394037   -30.416474   102.558310                       3
# 4   0.360202  0.670559     8.379403   -71.893118                       0
# ..       ...       ...          ...          ...                     ...
# 78  0.570861  0.769341   207.782714   -16.902844                       2
# 79  0.439499  0.803298    87.203198   -62.216471                       5
# 80  0.482638  0.406441   112.844774    31.419288                       8
# 81  0.471017  0.765191    84.992897    12.211219                       8
# 82  0.615642  0.484134   191.324003    37.750411                       2
#
#     Expression
# 0        tenth
# 1       second
# 2       second
# 3       fourth
# 4        first
# ..         ...
# 78       third
# 79       sixth
# 80       ninth
# 81       ninth
# 82       third
#
# [83 rows x 15333 columns]

# %%
exp_pca_kmeans_40 = pd.concat([expression.reset_index(drop = True), pd.DataFrame(scores_pca_40)], axis = 1)
labels = [i for i in range(0, len(expression.columns))] + ['Component 1']
exp_pca_kmeans_40.columns = labels

# Add the PCA K-means Clustering labels
exp_pca_kmeans_40['Expression K-Means PCA'] = kmeans_pca_40.labels_

exp_pca_kmeans_40['Expression'] = exp_pca_kmeans_40['Expression K-Means PCA'].map({0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth', 6:'seventh'})
exp_pca_kmeans_40
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.454583  0.658482  0.277650  0.357625  0.347462  0.497014  0.349346
# 1   0.706707  0.671063  0.406233  0.582556  0.267532  0.256723  0.484846
# 2   0.566528  0.675010  0.437712  0.468049  0.425430  0.446146  0.596285
# 3   0.212931  0.576003  0.357136  0.438805  0.373285  0.268619  0.589126
# 4   0.642248  0.593896  0.542412  0.394510  0.312705  0.625741  0.451634
# ..       ...       ...       ...       ...       ...       ...       ...
# 78  0.797560  0.222321  0.828974  0.535699  0.365279  0.595596  0.628648
# 79  0.743788  0.410607  0.453053  0.549809  0.458905  0.242426  0.256931
# 80  0.389645  0.276079  0.472205  0.629451  0.648575  0.561573  0.339787
# 81  0.834718  0.606113  0.341910  0.516733  0.511969  0.204136  0.207806
# 82  0.460944  0.198541  0.763409  0.526759  0.601813  0.560663  0.591394
#
#            7         8         9  ...     15322     15323     15324     15325  \
# 0   0.724353  0.367414  0.669540  ...  0.446169  0.552484  0.308915  0.704540
# 1   0.812316  0.459672  0.597053  ...  0.540830  0.458972  0.246902  0.672475
# 2   0.841651  0.419038  0.627651  ...  0.402906  0.441906  0.332620  0.755129
# 3   0.727150  0.526787  0.710701  ...  0.385504  0.531667  0.403771  0.738577
# 4   0.768109  0.341174  0.590407  ...  0.444794  0.362994  0.527073  0.680514
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 78  0.187954  0.521689  0.653557  ...  0.547770  0.439937  0.777148  0.266571
# 79  0.348701  0.535722  0.721475  ...  0.657642  0.720752  0.542317  0.559660
# 80  0.517898  0.725916  0.225080  ...  0.627132  0.474090  0.549538  0.374396
# 81  0.483309  0.554375  0.579146  ...  0.773956  0.633343  0.626717  0.344730
# 82  0.332751  0.708555  0.292948  ...  0.558695  0.557970  0.551906  0.332730
#
#        15326     15327     15328  Component 1  Expression K-Means PCA  \
# 0   0.629293  0.621094  0.527410   -46.456043                       5
# 1   0.601816  0.431178  0.598830   -33.279021                       2
# 2   0.778413  0.374840  0.520263   -50.369155                       5
# 3   0.770315  0.727547  0.394037   -30.416474                       2
# 4   0.388747  0.360202  0.670559     8.379403                       0
# ..       ...       ...       ...          ...                     ...
# 78  0.409345  0.570861  0.769341   207.782714                       6
# 79  0.184873  0.439499  0.803298    87.203198                       3
# 80  0.279621  0.482638  0.406441   112.844774                       3
# 81  0.199706  0.471017  0.765191    84.992897                       3
# 82  0.443646  0.615642  0.484134   191.324003                       6
#
#     Expression
# 0        sixth
# 1        third
# 2        sixth
# 3        third
# 4        first
# ..         ...
# 78     seventh
# 79      fourth
# 80      fourth
# 81      fourth
# 82     seventh
#
# [83 rows x 15332 columns]

# %%
# Plot the three PCA components with largest variance for 80% variance capture
x = exp_pca_kmeans_80['Component 1']
y = exp_pca_kmeans_80['Component 2']
z = exp_pca_kmeans_80['Component 3']

# Axes instance
fig = plt.figure(figsize=(6, 6))
ax = Axes3D(fig)
fig.add_axes(ax)

# Seaborn colormap
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# Plot
sc = ax.scatter(x, y, z, s=40, c=x, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Component 1')
ax.set_ylabel('Component 2')
ax.set_zlabel('Component 3')

# Legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.title('Brain Region Clusters by PCA Components')
plt.show()

# %%
# Plot the two PCA components for 50% variance capture
x = exp_pca_kmeans_50['Component 1']
y = exp_pca_kmeans_50['Component 2']
plt.figure(figsize=(10, 8))
sns.scatterplot(x = x, y = y, hue = exp_pca_kmeans_50['Expression'])
plt.title('Gene Clusters by PCA Components')
plt.show()

# %%
# Plot the PCA componentfor 40% variance capture
plt.figure(figsize=(10, 8))
sns.stripplot(data = exp_pca_kmeans_40['Component 1'])
plt.title('Gene Clusters by PCA Components')
plt.show()
